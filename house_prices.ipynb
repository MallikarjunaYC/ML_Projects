# %%
import numpy as np # for numeric calculation
import pandas as pd # for data analysis and manupulation
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for data visualization

# %%
dataset = pd.read_csv("D:/mallikarjuna/ML_Projects/house_price/california_housing.csv")

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataset_original = dataset

# %%
# removing the dependent value 'median_house_value'- 
dataset = dataset.drop('median_house_value', axis = 1)

# %%
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataset.hist(figsize = (10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>, <Axes: >]],
#       dtype=object)

# %%
dataset = dataset.drop(columns = ['ocean_proximity'])

# %%
plt.figure(figsize = (10,8))
sns.heatmap(dataset.corr(), annot = True, annot_kws={"size": 10})
sns.set(font_scale=.9)

# %%
dataset['total_rooms'] = np.log(dataset['total_rooms'] + 1)
dataset['total_bedrooms'] = np.log(dataset['total_bedrooms'] + 1)
dataset['population'] = np.log(dataset['population'] + 1)
dataset['households'] = np.log(dataset['households'] + 1)

# %%
dataset.hist(figsize = (10,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>, <Axes: >]],
#       dtype=object)

# %%
dataset['ocean_proximity'] = dataset_original['ocean_proximity']

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0     6.781058        4.867534
# 1    -122.22     37.86                21.0     8.867850        7.009409
# 2    -122.24     37.85                52.0     7.291656        5.252273
# 3    -122.25     37.85                52.0     7.150701        5.463832
# 4    -122.25     37.85                52.0     7.395108        5.638355
#
#    population  households  median_income ocean_proximity
# 0    5.777652    4.844187         8.3252        NEAR BAY
# 1    7.784057    7.037906         8.3014        NEAR BAY
# 2    6.208590    5.181784         7.2574        NEAR BAY
# 3    6.326149    5.393628         5.6431        NEAR BAY
# 4    6.338594    5.560682         3.8462        NEAR BAY

# %%
dataset['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# convert the 'ocean_proximity' column using one-hot encoding
pd.get_dummies(dataset.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0          False   False   False      True       False
# 1          False   False   False      True       False
# 2          False   False   False      True       False
# 3          False   False   False      True       False
# 4          False   False   False      True       False
# ...          ...     ...     ...       ...         ...
# 20635      False    True   False     False       False
# 20636      False    True   False     False       False
# 20637      False    True   False     False       False
# 20638      False    True   False     False       False
# 20639      False    True   False     False       False
#
# [20640 rows x 5 columns]

# %%
dataset = dataset.join(pd.get_dummies(dataset.ocean_proximity))

# %%
dataset = dataset.drop(columns = ['ocean_proximity'])

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0     6.781058        4.867534
# 1    -122.22     37.86                21.0     8.867850        7.009409
# 2    -122.24     37.85                52.0     7.291656        5.252273
# 3    -122.25     37.85                52.0     7.150701        5.463832
# 4    -122.25     37.85                52.0     7.395108        5.638355
#
#    population  households  median_income  <1H OCEAN  INLAND  ISLAND  NEAR BAY  \
# 0    5.777652    4.844187         8.3252      False   False   False      True
# 1    7.784057    7.037906         8.3014      False   False   False      True
# 2    6.208590    5.181784         7.2574      False   False   False      True
# 3    6.326149    5.393628         5.6431      False   False   False      True
# 4    6.338594    5.560682         3.8462      False   False   False      True
#
#    NEAR OCEAN
# 0       False
# 1       False
# 2       False
# ...

# %%
dataset.shape
# Out:
# (20640, 13)

# %%
plt.figure(figsize = (10,8))
sns.heatmap(dataset.corr(), annot = True, annot_kws={"size": 10})
sns.set(font_scale=.9)

# %%
dataset['median_house_value'] = dataset_original['median_house_value']

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='latitude', y='longitude', data = dataset, hue = 'median_house_value')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
dataset['bedroom_ratio'] = dataset['total_bedrooms'] / dataset['total_rooms']
dataset['household_rooms'] = dataset['total_rooms'] / dataset['households']

# %%
plt.figure(figsize = (10,8))
sns.heatmap(dataset.corr(), annot = True, annot_kws={"size": 8})
sns.set(font_scale=.9)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
dataset = dataset.dropna()

# %%
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0     6.781058        4.867534
# 1    -122.22     37.86                21.0     8.867850        7.009409
# 2    -122.24     37.85                52.0     7.291656        5.252273
# 3    -122.25     37.85                52.0     7.150701        5.463832
# 4    -122.25     37.85                52.0     7.395108        5.638355
#
#    population  households  median_income  <1H OCEAN  INLAND  ISLAND  NEAR BAY  \
# 0    5.777652    4.844187         8.3252      False   False   False      True
# 1    7.784057    7.037906         8.3014      False   False   False      True
# 2    6.208590    5.181784         7.2574      False   False   False      True
# 3    6.326149    5.393628         5.6431      False   False   False      True
# 4    6.338594    5.560682         3.8462      False   False   False      True
#
# ...

# %%
X = dataset.drop(['median_house_value'], axis = 1)

y = dataset['median_house_value']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6390     -118.05     34.15                32.0     8.543251        6.501290
# 11454    -118.01     33.67                16.0     8.183677        6.660575
# 16036    -122.46     37.72                48.0     7.433075        5.828946
# 3582     -118.55     34.24                21.0     8.657303        6.987490
# 12047    -117.53     33.88                22.0     7.957177        6.504288
# ...          ...       ...                 ...          ...             ...
# 5599     -118.27     33.79                36.0     7.704812        6.331502
# 2096     -119.76     36.75                41.0     7.363280        6.035481
# 11350    -117.92     33.76                26.0     6.665684        5.181784
# 5646     -118.29     33.75                37.0     7.185387        5.680173
# 18820    -120.24     39.67                52.0     5.693732        4.158883
#
# ...

# %%
reg.score(X_test, y_test)
# Out:
# 0.6709225255799128

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_s = scaler.fit_transform(X_train)
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6709225255799127

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, y_test)
# Out:
# 0.8277580960475887

# %%
forest.fit(X_train_s, y_train)
forest.score(X_test_s, y_test)
# Out:
# 0.8261390919244012
